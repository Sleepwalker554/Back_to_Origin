# %%
from pathlib import Path
from subtract_audio import process_dataset

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Demucs'
output_dir = '../ad_detection/data/residual/Pitt-residual-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 59587.98it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 59620.94it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Denoiser'
output_dir = '../ad_detection/data/residual/Pitt-residual-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 61241.80it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 62172.12it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-FRCRN_SE'
output_dir = '../ad_detection/data/residual/Pitt-residual-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 60881.81it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 63528.26it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-MossFormer'
output_dir = '../ad_detection/data/residual/Pitt-residual-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 61072.30it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 61760.30it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Resemble'
output_dir = '../ad_detection/data/residual/Pitt-residual-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 60987.90it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 61438.25it/s]
# []
