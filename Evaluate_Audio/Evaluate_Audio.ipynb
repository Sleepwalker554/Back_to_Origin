# %%
from evaluate_audio_quality import evaluate_directory

# %%
# audio_dir = "../ad_detection/data/raw/ADReSS"

# df = evaluate_directory(audio_dir)
# df

# %%
audio_dir = "../ad_detection/data/raw/ADReSSo"

df = evaluate_directory(audio_dir)
df
# Out:
# 目录: ../ad_detection/data/raw/ADReSSo
# 找到 237 个音频文件
# 评估中: 100%|██████████| 237/237 [02:09<00:00,  1.83it/s]
# === DNSMOS 平均分 (../ad_detection/data/raw/ADReSSo) ===
#   OVRL (Overall):    2.5222
#   SIG  (Signal):     3.0373
#   BAK  (Background): 3.1829
#   共评估 237 个文件
# {'OVRL': 2.5222, 'SIG': 3.0373, 'BAK': 3.1829}

# %%
audio_dir = "../ad_detection/data/raw/ADReSS-M"

df = evaluate_directory(audio_dir)
df
# Out:
# 目录: ../ad_detection/data/raw/ADReSS-M
# 找到 237 个音频文件
# 评估中: 100%|██████████| 237/237 [02:09<00:00,  1.84it/s]
# === DNSMOS 平均分 (../ad_detection/data/raw/ADReSS-M) ===
#   OVRL (Overall):    2.3128
#   SIG  (Signal):     2.9805
#   BAK  (Background): 2.6973
#   共评估 237 个文件
# {'OVRL': 2.3128, 'SIG': 2.9805, 'BAK': 2.6973}

# %%
# df_mossformer = evaluate_directory("../ad_detection/data/denoised/Pitt-origin-MossFormer")
# df_mossformer

# %%
# df_frcrn = evaluate_directory("../ad_detection/data/denoised/Pitt-origin-FRCRN_SE")
# df_frcrn

# %%
# df_demucs = evaluate_directory("../ad_detection/data/denoised/Pitt-origin-Demucs")
# df_demucs

# %%
# df_denoiser = evaluate_directory("../ad_detection/data/denoised/Pitt-origin-Denoiser")
# df_denoiser

# %%
# df_resemble = evaluate_directory("../ad_detection/data/denoised/Pitt-origin-Resemble")
# df_resemble
