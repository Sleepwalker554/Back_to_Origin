# %%
import sys
from pathlib import Path
import torch

script_dir = Path.cwd()
sys.path.insert(0, str(script_dir.parent.parent / "train"))

from utils.config import PROJECT_ROOT
from utils.data_split import create_split
from XLSR_model.extract_feature import extract_feature
from utils.visualization import plot_training_curves
from utils.dataset import create_dataloaders
from XLSR_model.train import train
import numpy as np

# %%
DATASET_NAME = "Pitt-origin"
data_version = "raw"

# %%
# RAW_AUDIO_DIR = PROJECT_ROOT / f"data/denoised/{DATASET_NAME}"
RAW_AUDIO_DIR = PROJECT_ROOT / f"data/{data_version}/{DATASET_NAME}"

XLSR_FEATURES_DIR = PROJECT_ROOT / f"data/processed/{DATASET_NAME}_xlsr_features"
FEATURE_DIR_NAME = f"{DATASET_NAME}_xlsr_features"
MODEL_OUTPUT_DIR = PROJECT_ROOT / f"models/{DATASET_NAME}_xlsr_multi_seed"

# %%
if torch.cuda.is_available():
      device = torch.device('cuda')
      accelerator = 'gpu'
elif torch.backends.mps.is_available():
      device = torch.device('mps')
      accelerator = 'mps'
else:
      device = torch.device('cpu')
      accelerator = 'cpu'
print(f"Using {device}")

# %% [markdown]
# ## Step 1: Train/Validation Set Split

# %%
TRAIN_CSV, VAL_CSV = create_split(DATASET_NAME)

# %% [markdown]
# ## Step 2: Extract XLSR Features

# %%
ssl_model = extract_feature(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    raw_audio_dir=RAW_AUDIO_DIR,
    xlsr_features_dir=XLSR_FEATURES_DIR,
    device=device,
)
# Out:
# /root/autodl-tmp/envs/madress/lib/python3.9/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# XLSR: Using original pretrained model
#
# === Extracting XLSR features for Train Set ===
# Extracting Train Set: 100%|██████████| 441/441 [12:28<00:00,  1.70s/it]
# Done: 441 extracted, 0 skipped, 0 errors (total 441)
#
# === Extracting XLSR features for Val Set ===
# Extracting Val Set: 100%|██████████| 111/111 [02:54<00:00,  1.57s/it]
# Done: 111 extracted, 0 skipped, 0 errors (total 111)

# %% [markdown]
# ## Step 4: Create Data Loaders

# %%
train_loader = create_dataloaders(data_csv=TRAIN_CSV, xlsr=True)

val_loader = create_dataloaders(data_csv=VAL_CSV, xlsr=True)
# Out:
# Loading completed: 441 samples
# Control: 194, Dementia: 247
#
#
# Loading completed: 111 samples
# Control: 49, Dementia: 62

# %% [markdown]
# ## Step 5: Define Training Function and Model

# %%
all_results = {
    'seeds': [], 
    'val_accs': [], 
    'val_losses': [], 
    'control_accs': [], 
    'dementia_accs': [], 
    'f1_scores': []
}

# %% [markdown]
# ### 1st Random Seed = 21

# %%
seed, metrics, history = train(seed=21, 
                               train_loader=train_loader, 
                               val_loader=val_loader, 
                               output_dir=MODEL_OUTPUT_DIR, 
                               device=device)

all_results['seeds'].append(seed)
all_results['val_accs'].append(metrics['val_acc'])
all_results['val_losses'].append(metrics['val_loss'])
all_results['control_accs'].append(metrics['control_acc'])
all_results['dementia_accs'].append(metrics['dementia_acc'])
all_results['f1_scores'].append(metrics['f1_score'])

# Plot training curves
plot_training_curves(
    epochs=history['epochs'],
    train_loss=history['train_losses'],
    val_loss=history['val_losses'],
    train_acc=history['train_accs'],
    val_acc=history['val_accs'],
    title_prefix=f'Seed {seed}'
)
# Out:
# Seed 21:
# Val Acc=67.57%, F1=0.6727, Val Loss=0.6313
# Control Acc=77.55%, Dementia Acc=59.68%
# Early stop at: epoch 24 (best epoch: 14)

# %% [markdown]
# ### 2nd Random Seed = 42

# %%
seed, metrics, history = train(seed=42, 
                               train_loader=train_loader, 
                               val_loader=val_loader, 
                               output_dir=MODEL_OUTPUT_DIR, 
                               device=device)

all_results['seeds'].append(seed)
all_results['val_accs'].append(metrics['val_acc'])
all_results['val_losses'].append(metrics['val_loss'])
all_results['control_accs'].append(metrics['control_acc'])
all_results['dementia_accs'].append(metrics['dementia_acc'])
all_results['f1_scores'].append(metrics['f1_score'])

# Plot training curves
plot_training_curves(
    epochs=history['epochs'],
    train_loss=history['train_losses'],
    val_loss=history['val_losses'],
    train_acc=history['train_accs'],
    val_acc=history['val_accs'],
    title_prefix=f'Seed {seed}'
)
# Out:
# Seed 42:
# Val Acc=67.57%, F1=0.6327, Val Loss=0.6767
# Control Acc=89.80%, Dementia Acc=50.00%
# Early stop at: epoch 23 (best epoch: 13)

# %% [markdown]
# ### 3rd Random Seed = 84

# %%
seed, metrics, history = train(seed=84, 
                               train_loader=train_loader, 
                               val_loader=val_loader, 
                               output_dir=MODEL_OUTPUT_DIR, 
                               device=device)

all_results['seeds'].append(seed)
all_results['val_accs'].append(metrics['val_acc'])
all_results['val_losses'].append(metrics['val_loss'])
all_results['control_accs'].append(metrics['control_acc'])
all_results['dementia_accs'].append(metrics['dementia_acc'])
all_results['f1_scores'].append(metrics['f1_score'])

# Plot training curves
plot_training_curves(
    epochs=history['epochs'],
    train_loss=history['train_losses'],
    val_loss=history['val_losses'],
    train_acc=history['train_accs'],
    val_acc=history['val_accs'],
    title_prefix=f'Seed {seed}'
)
# Out:
# Seed 84:
# Val Acc=71.17%, F1=0.7091, Val Loss=0.7054
# Control Acc=81.63%, Dementia Acc=62.90%
# Early stop at: epoch 33 (best epoch: 23)

# %% [markdown]
# ### 4th Random Seed = 168

# %%
seed, metrics, history = train(seed=168, 
                               train_loader=train_loader, 
                               val_loader=val_loader, 
                               output_dir=MODEL_OUTPUT_DIR, 
                               device=device)

all_results['seeds'].append(seed)
all_results['val_accs'].append(metrics['val_acc'])
all_results['val_losses'].append(metrics['val_loss'])
all_results['control_accs'].append(metrics['control_acc'])
all_results['dementia_accs'].append(metrics['dementia_acc'])
all_results['f1_scores'].append(metrics['f1_score'])

# Plot training curves
plot_training_curves(
    epochs=history['epochs'],
    train_loss=history['train_losses'],
    val_loss=history['val_losses'],
    train_acc=history['train_accs'],
    val_acc=history['val_accs'],
    title_prefix=f'Seed {seed}'
)
# Out:
# Seed 168:
# Val Acc=67.57%, F1=0.7097, Val Loss=0.6485
# Control Acc=63.27%, Dementia Acc=70.97%
# Early stop at: epoch 31 (best epoch: 21)

# %% [markdown]
# ### 5th Random Seed = 336

# %%
seed, metrics, history = train(seed=336, 
                               train_loader=train_loader, 
                               val_loader=val_loader, 
                               output_dir=MODEL_OUTPUT_DIR, 
                               device=device)

all_results['seeds'].append(seed)
all_results['val_accs'].append(metrics['val_acc'])
all_results['val_losses'].append(metrics['val_loss'])
all_results['control_accs'].append(metrics['control_acc'])
all_results['dementia_accs'].append(metrics['dementia_acc'])
all_results['f1_scores'].append(metrics['f1_score'])

# Plot training curves
plot_training_curves(
    epochs=history['epochs'],
    train_loss=history['train_losses'],
    val_loss=history['val_losses'],
    train_acc=history['train_accs'],
    val_acc=history['val_accs'],
    title_prefix=f'Seed {seed}'
)
# Out:
# Seed 336:
# Val Acc=70.27%, F1=0.7402, Val Loss=0.6346
# Control Acc=63.27%, Dementia Acc=75.81%
# Early stop at: epoch 30 (best epoch: 20)

# %% [markdown]
# ## Step 6: Summary of Results

# %%
seeds = all_results['seeds']
val_accs = [acc*100 for acc in all_results['val_accs']]
val_losses = all_results['val_losses']
control_accs = [acc*100 for acc in all_results['control_accs']]
dementia_accs = [acc*100 for acc in all_results['dementia_accs']]
f1_scores = all_results['f1_scores']

# Calculate statistics (mean and std)
mean_acc = np.mean(val_accs)
std_acc = np.std(val_accs, ddof=1)

mean_loss = np.mean(val_losses)
std_loss = np.std(val_losses, ddof=1)

mean_control_acc = np.mean(control_accs)
std_control_acc = np.std(control_accs, ddof=1)

mean_dementia_acc = np.mean(dementia_accs)
std_dementia_acc = np.std(dementia_accs, ddof=1)

mean_f1 = np.mean(f1_scores)
std_f1 = np.std(f1_scores, ddof=1)

print(f"\nMean Validation Accuracy: {mean_acc:.2f}% ± {std_acc:.2f}%")
print(f"Mean Validation Loss: {mean_loss:.4f} ± {std_loss:.4f}")
print(f"Mean Control Accuracy: {mean_control_acc:.2f}% ± {std_control_acc:.2f}%")
print(f"Mean Dementia Accuracy: {mean_dementia_acc:.2f}% ± {std_dementia_acc:.2f}%")
print(f"Mean F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")

print(f"\nDetailed Results:")
for i, seed in enumerate(seeds):
    print(f"Seed {seed}: Acc={val_accs[i]:.2f}%, Loss={val_losses[i]:.4f}, "
          f"Control Acc={control_accs[i]:.2f}%, Dementia Acc={dementia_accs[i]:.2f}%, F1={f1_scores[i]:.4f}")
# Out:
# Mean Validation Accuracy: 68.83% ± 1.76%
# Mean Validation Loss: 0.6593 ± 0.0314
# Mean Control Accuracy: 75.10% ± 11.67%
# Mean Dementia Accuracy: 63.87% ± 10.05%
# Mean F1 Score: 0.6929 ± 0.0413
#
# Detailed Results:
# Seed 21: Acc=67.57%, Loss=0.6313, Control Acc=77.55%, Dementia Acc=59.68%, F1=0.6727
# Seed 42: Acc=67.57%, Loss=0.6767, Control Acc=89.80%, Dementia Acc=50.00%, F1=0.6327
# Seed 84: Acc=71.17%, Loss=0.7054, Control Acc=81.63%, Dementia Acc=62.90%, F1=0.7091
# Seed 168: Acc=67.57%, Loss=0.6485, Control Acc=63.27%, Dementia Acc=70.97%, F1=0.7097
# Seed 336: Acc=70.27%, Loss=0.6346, Control Acc=63.27%, Dementia Acc=75.81%, F1=0.7402

# %% [markdown]
# ## Step 7: Test Best Model on Multiple Datasets

# %%
# Find the best model: highest accuracy, then lowest loss if tied
max_acc = max(all_results['val_accs'])
max_acc_indices = [i for i, acc in enumerate(all_results['val_accs']) if acc == max_acc]

# If multiple models have the same max accuracy, choose the one with lowest loss
if len(max_acc_indices) > 1:
    print(f"Multiple models with accuracy {max_acc*100:.2f}%, selecting one with lowest loss")
    best_idx = min(max_acc_indices, key=lambda i: all_results['val_losses'][i])
else:
    best_idx = max_acc_indices[0]

# Get best model info
BEST_SEED = all_results['seeds'][best_idx]
BEST_VAL_ACC = all_results['val_accs'][best_idx] * 100
BEST_VAL_LOSS = all_results['val_losses'][best_idx]
BEST_F1 = all_results['f1_scores'][best_idx]
BEST_MODEL_PATH = MODEL_OUTPUT_DIR / f"seed_{BEST_SEED}" / "best.pth"

# %%
# Load the best model
from XLSR_model.model import AD_XLSR_Model
from XLSR_model.test import test_on_dataset, test_on_dataset_with_val_csv

# Create model with XLSR configuration
test_model = AD_XLSR_Model()

# Load checkpoint (state_dict was saved directly)
checkpoint = torch.load(BEST_MODEL_PATH, map_location=device)
test_model.load_state_dict(checkpoint)
test_model = test_model.to(device)
test_model.eval()

# Define reference validation CSV for consistent testing across datasets
# Use Pitt-Best validation set as the reference for all three datasets
REFERENCE_VAL_CSV = PROJECT_ROOT / f"data/processed/{DATASET_NAME}-xlsr-val.csv"
print(f"Reference VAL_CSV: {REFERENCE_VAL_CSV}")
# Out:
# Reference VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-origin-xlsr-val.csv

# %%
with_val_csv_datasets = [
    ("Pitt", "data/raw/Pitt"),
    ("Pitt-Demucs", "data/denoised/Pitt-Demucs"),
    ("Pitt-Denoiser", "data/denoised/Pitt-Denoiser"),
    ("Pitt-FRCRN_SE", "data/denoised/Pitt-FRCRN_SE"),
    ("Pitt-MossFormer", "data/denoised/Pitt-MossFormer"),
    ("Pitt-Resemble", "data/denoised/Pitt-Resemble"),
]
all_test_results = {}
for name, audio_dir in with_val_csv_datasets:
    all_test_results[name] = test_on_dataset_with_val_csv(
        reference_val_csv=REFERENCE_VAL_CSV,
        dataset_name=name, model=test_model, device=device,
        ssl_model=ssl_model, raw_audio_dir=audio_dir)

test_datasets = [
    ("ADReSS", "data/raw/ADReSS"),
    ("Lu", "data/raw/Lu"),
    ("Lu-Demucs", "data/denoised/Lu-Demucs"),
    ("Lu-Denoiser", "data/denoised/Lu-Denoiser"),
    ("Lu-FRCRN_SE", "data/denoised/Lu-FRCRN_SE"),
    ("Lu-MossFormer", "data/denoised/Lu-MossFormer"),
    ("Lu-Resemble", "data/denoised/Lu-Resemble"),
]
for name, audio_dir in test_datasets:
    all_test_results[name] = test_on_dataset(
        dataset_name=name, model=test_model, device=device,
        ssl_model=ssl_model, raw_audio_dir=audio_dir)

# Print summary table
print("\n" + "="*80)
print("SUMMARY OF ALL TEST RESULTS")
print("="*80)
print(f"{'Dataset':<20} {'Accuracy':<12} {'F1 Score':<12} {'Control Acc':<12} {'Dementia Acc':<12}")
print("-"*80)

for dataset_name, results in all_test_results.items():
    print(f"{dataset_name:<20} {results['accuracy']*100:>10.2f}%  {results['f1']:>10.4f}  "
          f"{results['control_acc']*100:>10.2f}%  {results['dementia_acc']*100:>10.2f}%")

print("="*80)
# Out:
# ============================================================
# Testing on Pitt Dataset (using reference VAL_CSV)
# ============================================================
#
# Reading reference VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-origin-xlsr-val.csv
# Found 111 samples in reference VAL_CSV
# Checking audio file existence in /root/autodl-tmp/Back_to_Origin/ad_detection/data/raw/Pitt...
# Audio files found: 111/111
#
# Creating target VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-xlsr-val.csv
# Target VAL_CSV created with 111 samples
#
#
# === Extracting XLSR features for Pitt Validation Set ===
# Extracting Pitt Validation Set: 100%|██████████| 111/111 [00:01<00:00, 59.45it/s]
# Done: 2 extracted, 109 skipped, 0 errors (total 111)
# Loading completed: 111 samples
# Control: 49, Dementia: 62
# Testing on Pitt: 100%|██████████| 4/4 [00:00<00:00, 17.90it/s]
# Overall Accuracy: 56.76%, F1 Score: 0.5472
# Control Accuracy: 69.39%, Dementia Accuracy: 46.77%
#
# ============================================================
# Testing on Pitt-Demucs Dataset (using reference VAL_CSV)
# ============================================================
#
# Reading reference VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-origin-xlsr-val.csv
# Found 111 samples in reference VAL_CSV
# Checking audio file existence in /root/autodl-tmp/Back_to_Origin/ad_detection/data/denoised/Pitt-Demucs...
# Audio files found: 111/111
#
# Creating target VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-Demucs-xlsr-val.csv
# Target VAL_CSV created with 111 samples
#
#
# === Extracting XLSR features for Pitt-Demucs Validation Set ===
# Extracting Pitt-Demucs Validation Set: 100%|██████████| 111/111 [00:01<00:00, 60.90it/s]
# Done: 2 extracted, 109 skipped, 0 errors (total 111)
# Loading completed: 111 samples
# Control: 49, Dementia: 62
# Testing on Pitt-Demucs: 100%|██████████| 4/4 [00:00<00:00, 20.39it/s]
# Overall Accuracy: 54.95%, F1 Score: 0.5098
# Control Accuracy: 71.43%, Dementia Accuracy: 41.94%
# ============================================================
# Testing on Pitt-Denoiser Dataset (using reference VAL_CSV)
# ============================================================
#
# Reading reference VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-origin-xlsr-val.csv
# Found 111 samples in reference VAL_CSV
# Checking audio file existence in /root/autodl-tmp/Back_to_Origin/ad_detection/data/denoised/Pitt-Denoiser...
# Audio files found: 111/111
#
# Creating target VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-Denoiser-xlsr-val.csv
# Target VAL_CSV created with 111 samples
#
#
# === Extracting XLSR features for Pitt-Denoiser Validation Set ===
# Extracting Pitt-Denoiser Validation Set: 100%|██████████| 111/111 [00:00<00:00, 561.88it/s]
# Done: 2 extracted, 109 skipped, 0 errors (total 111)
# Loading completed: 111 samples
# Control: 49, Dementia: 62
# Testing on Pitt-Denoiser: 100%|██████████| 4/4 [00:00<00:00, 21.42it/s]
# Overall Accuracy: 56.76%, F1 Score: 0.5862
# Control Accuracy: 59.18%, Dementia Accuracy: 54.84%
#
# ============================================================
# Testing on Pitt-FRCRN_SE Dataset (using reference VAL_CSV)
# ============================================================
#
# Reading reference VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-origin-xlsr-val.csv
# Found 111 samples in reference VAL_CSV
# Checking audio file existence in /root/autodl-tmp/Back_to_Origin/ad_detection/data/denoised/Pitt-FRCRN_SE...
# Audio files found: 111/111
#
# Creating target VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-FRCRN_SE-xlsr-val.csv
# Target VAL_CSV created with 111 samples
#
#
# === Extracting XLSR features for Pitt-FRCRN_SE Validation Set ===
# Extracting Pitt-FRCRN_SE Validation Set: 100%|██████████| 111/111 [00:00<00:00, 685.43it/s]
# Done: 2 extracted, 109 skipped, 0 errors (total 111)
# Loading completed: 111 samples
# Control: 49, Dementia: 62
# Testing on Pitt-FRCRN_SE: 100%|██████████| 4/4 [00:00<00:00, 19.04it/s]
# Overall Accuracy: 57.66%, F1 Score: 0.5913
# Control Accuracy: 61.22%, Dementia Accuracy: 54.84%
#
# ============================================================
# Testing on Pitt-MossFormer Dataset (using reference VAL_CSV)
# ============================================================
#
# Reading reference VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-origin-xlsr-val.csv
# Found 111 samples in reference VAL_CSV
# Checking audio file existence in /root/autodl-tmp/Back_to_Origin/ad_detection/data/denoised/Pitt-MossFormer...
# Audio files found: 111/111
#
# Creating target VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-MossFormer-xlsr-val.csv
# Target VAL_CSV created with 111 samples
#
#
# === Extracting XLSR features for Pitt-MossFormer Validation Set ===
# Extracting Pitt-MossFormer Validation Set: 100%|██████████| 111/111 [00:00<00:00, 681.35it/s]
# Done: 2 extracted, 109 skipped, 0 errors (total 111)
# Loading completed: 111 samples
# Control: 49, Dementia: 62
# Testing on Pitt-MossFormer: 100%|██████████| 4/4 [00:00<00:00, 21.30it/s]
# Overall Accuracy: 52.25%, F1 Score: 0.4536
# Control Accuracy: 73.47%, Dementia Accuracy: 35.48%
#
# ============================================================
# Testing on Pitt-Resemble Dataset (using reference VAL_CSV)
# ============================================================
#
# Reading reference VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-origin-xlsr-val.csv
# Found 111 samples in reference VAL_CSV
# Checking audio file existence in /root/autodl-tmp/Back_to_Origin/ad_detection/data/denoised/Pitt-Resemble...
# Audio files found: 111/111
#
# Creating target VAL_CSV: /root/autodl-tmp/Back_to_Origin/ad_detection/data/processed/Pitt-Resemble-xlsr-val.csv
# Target VAL_CSV created with 111 samples
#
#
# === Extracting XLSR features for Pitt-Resemble Validation Set ===
# Extracting Pitt-Resemble Validation Set: 100%|██████████| 111/111 [00:01<00:00, 59.56it/s]
# Done: 2 extracted, 109 skipped, 0 errors (total 111)
# Loading completed: 111 samples
# Control: 49, Dementia: 62
# Testing on Pitt-Resemble: 100%|██████████| 4/4 [00:00<00:00, 19.35it/s]
# Overall Accuracy: 54.05%, F1 Score: 0.4742
# Control Accuracy: 75.51%, Dementia Accuracy: 37.10%
#
# ============================================================
# Testing on ADReSS Dataset
# ============================================================
#
#
# === Extracting XLSR features for ADReSS Test Set ===
# Extracting ADReSS Test Set: 100%|██████████| 156/156 [00:00<00:00, 44091.07it/s]
# Done: 0 extracted, 156 skipped, 0 errors (total 156)
# Loading completed: 156 samples
# Control: 78, Dementia: 78
# Testing on ADReSS: 100%|██████████| 5/5 [00:00<00:00, 17.20it/s]
# Overall Accuracy: 71.79%, F1 Score: 0.6986
# Control Accuracy: 78.21%, Dementia Accuracy: 65.38%
#
# ============================================================
# Testing on Lu Dataset
# ============================================================
#
#
# === Extracting XLSR features for Lu Test Set ===
# Extracting Lu Test Set: 100%|██████████| 74/74 [00:00<00:00, 31590.69it/s]
# Done: 0 extracted, 74 skipped, 0 errors (total 74)
# Loading completed: 74 samples
# Control: 36, Dementia: 38
# Testing on Lu: 100%|██████████| 3/3 [00:00<00:00, 27.26it/s]
# Overall Accuracy: 67.57%, F1 Score: 0.7000
# Control Accuracy: 61.11%, Dementia Accuracy: 73.68%
#
# ============================================================
# Testing on Lu-Demucs Dataset
# ============================================================
#
#
# === Extracting XLSR features for Lu-Demucs Test Set ===
# Extracting Lu-Demucs Test Set: 100%|██████████| 74/74 [00:00<00:00, 34854.41it/s]
# Done: 0 extracted, 74 skipped, 0 errors (total 74)
# Loading completed: 74 samples
# Control: 36, Dementia: 38
# Testing on Lu-Demucs: 100%|██████████| 3/3 [00:00<00:00, 38.90it/s]
# Overall Accuracy: 66.22%, F1 Score: 0.6914
# Control Accuracy: 58.33%, Dementia Accuracy: 73.68%
#
# ============================================================
# Testing on Lu-Denoiser Dataset
# ============================================================
#
#
# === Extracting XLSR features for Lu-Denoiser Test Set ===
# Extracting Lu-Denoiser Test Set: 100%|██████████| 74/74 [00:00<00:00, 38017.94it/s]
# Done: 0 extracted, 74 skipped, 0 errors (total 74)
# Loading completed: 74 samples
# Control: 36, Dementia: 38
# Testing on Lu-Denoiser: 100%|██████████| 3/3 [00:00<00:00, 28.17it/s]
# Overall Accuracy: 67.57%, F1 Score: 0.7551
# Control Accuracy: 36.11%, Dementia Accuracy: 97.37%
#
# ============================================================
# Testing on Lu-FRCRN_SE Dataset
# ============================================================
#
#
# === Extracting XLSR features for Lu-FRCRN_SE Test Set ===
# Extracting Lu-FRCRN_SE Test Set: 100%|██████████| 74/74 [00:00<00:00, 37735.99it/s]
# Done: 0 extracted, 74 skipped, 0 errors (total 74)
# Loading completed: 74 samples
# Control: 36, Dementia: 38
# Testing on Lu-FRCRN_SE: 100%|██████████| 3/3 [00:00<00:00, 30.33it/s]
# Overall Accuracy: 74.32%, F1 Score: 0.7816
# Control Accuracy: 58.33%, Dementia Accuracy: 89.47%
#
# ============================================================
# Testing on Lu-MossFormer Dataset
# ============================================================
#
#
# === Extracting XLSR features for Lu-MossFormer Test Set ===
# Extracting Lu-MossFormer Test Set: 100%|██████████| 74/74 [00:00<00:00, 37818.75it/s]
# Done: 0 extracted, 74 skipped, 0 errors (total 74)
# Loading completed: 74 samples
# Control: 36, Dementia: 38
# Testing on Lu-MossFormer: 100%|██████████| 3/3 [00:00<00:00, 43.20it/s]
# Overall Accuracy: 63.51%, F1 Score: 0.7158
# Control Accuracy: 36.11%, Dementia Accuracy: 89.47%
#
# ============================================================
# Testing on Lu-Resemble Dataset
# ============================================================
#
#
# === Extracting XLSR features for Lu-Resemble Test Set ===
# Extracting Lu-Resemble Test Set: 100%|██████████| 74/74 [00:00<00:00, 37341.01it/s]
# Done: 0 extracted, 74 skipped, 0 errors (total 74)
# Loading completed: 74 samples
# Control: 36, Dementia: 38
# Testing on Lu-Resemble: 100%|██████████| 3/3 [00:00<00:00, 42.96it/s]
# Overall Accuracy: 71.62%, F1 Score: 0.7586
# Control Accuracy: 55.56%, Dementia Accuracy: 86.84%
#
# ================================================================================
# SUMMARY OF ALL TEST RESULTS
# ================================================================================
# Dataset              Accuracy     F1 Score     Control Acc  Dementia Acc
# --------------------------------------------------------------------------------
# Pitt                      56.76%      0.5472       69.39%       46.77%
# Pitt-Demucs               54.95%      0.5098       71.43%       41.94%
# Pitt-Denoiser             56.76%      0.5862       59.18%       54.84%
# Pitt-FRCRN_SE             57.66%      0.5913       61.22%       54.84%
# Pitt-MossFormer           52.25%      0.4536       73.47%       35.48%
# Pitt-Resemble             54.05%      0.4742       75.51%       37.10%
# ADReSS                    71.79%      0.6986       78.21%       65.38%
# Lu                        67.57%      0.7000       61.11%       73.68%
# Lu-Demucs                 66.22%      0.6914       58.33%       73.68%
# Lu-Denoiser               67.57%      0.7551       36.11%       97.37%
# Lu-FRCRN_SE               74.32%      0.7816       58.33%       89.47%
# Lu-MossFormer             63.51%      0.7158       36.11%       89.47%
# Lu-Resemble               71.62%      0.7586       55.56%       86.84%
# ================================================================================

# %%
torch.cuda.empty_cache()
