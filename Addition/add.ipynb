# %%
from add_audio import process_dataset
RAW_WEIGHT = 0.5

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Demucs'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 55062.47it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 59361.51it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Denoiser'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57394.49it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 58972.56it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-FRCRN_SE'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57997.92it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 60266.91it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-MossFormer'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 58681.94it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 60379.22it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Resemble'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57303.76it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 60258.51it/s]
# []

# %%
RAW_WEIGHT = 1.0

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Demucs'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 58284.33it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 59093.56it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Denoiser'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57168.21it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 58830.68it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-FRCRN_SE'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 56149.89it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 58937.70it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-MossFormer'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57164.99it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 58918.94it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Resemble'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57635.66it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 59356.08it/s]
# []

# %%
RAW_WEIGHT = 1.5

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Demucs'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 55936.38it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 60596.59it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Denoiser'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 58869.13it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 61154.15it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-FRCRN_SE'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57701.19it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 60294.95it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-MossFormer'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57400.98it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 58254.22it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Resemble'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 57885.46it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 58771.99it/s]
# []

# %%
RAW_WEIGHT = 0.5

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Demucs'
output_dir = '../ad_detection/data/add/Lu-add-0.5-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 501.76it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 34056.31it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Denoiser'
output_dir = '../ad_detection/data/add/Lu-add-0.5-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 98.11it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 38685.33it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-FRCRN_SE'
output_dir = '../ad_detection/data/add/Lu-add-0.5-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 128.28it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 35191.78it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-MossFormer'
output_dir = '../ad_detection/data/add/Lu-add-0.5-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 110.31it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 36606.24it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Resemble'
output_dir = '../ad_detection/data/add/Lu-add-0.5-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 712.08it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 37239.15it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,) ')]

# %%
RAW_WEIGHT = 1.0

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Demucs'
output_dir = '../ad_detection/data/add/Lu-add-1.0-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 682.90it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 25599.67it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Denoiser'
output_dir = '../ad_detection/data/add/Lu-add-1.0-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 141.91it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 35728.21it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-FRCRN_SE'
output_dir = '../ad_detection/data/add/Lu-add-1.0-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 145.32it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 35176.24it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-MossFormer'
output_dir = '../ad_detection/data/add/Lu-add-1.0-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 146.31it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 35261.85it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Resemble'
output_dir = '../ad_detection/data/add/Lu-add-1.0-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 712.25it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 38011.82it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,) ')]

# %%
RAW_WEIGHT = 1.5

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Demucs'
output_dir = '../ad_detection/data/add/Lu-add-1.5-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 721.31it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 35864.89it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Denoiser'
output_dir = '../ad_detection/data/add/Lu-add-1.5-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 137.49it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 37247.85it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-FRCRN_SE'
output_dir = '../ad_detection/data/add/Lu-add-1.5-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 122.29it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 34209.82it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-MossFormer'
output_dir = '../ad_detection/data/add/Lu-add-1.5-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 138.39it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 35961.99it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (598889,2) (598889,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (598889,2) (598889,) ')]

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Resemble'
output_dir = '../ad_detection/data/add/Lu-add-1.5-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 36/36 [00:00<00:00, 702.76it/s]
# 处理 Dementia: 100%|██████████| 38/38 [00:00<00:00, 34431.53it/s]
# 跳过了 1 个文件:
#   - F43_000.mp3: 处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,)
# [('F43_000.mp3',
#   '处理失败: operands could not be broadcast together with shapes (1650688,2) (1650688,) ')]
