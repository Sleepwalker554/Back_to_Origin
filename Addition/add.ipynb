# %%
from add_audio import process_dataset
RAW_WEIGHT = 0.5

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Demucs'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 56819.39it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 61108.02it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Denoiser'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 66120.88it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 61514.07it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-FRCRN_SE'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 29487.58it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 17254.08it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-MossFormer'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 34660.12it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 35528.38it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Resemble'
output_dir = '../ad_detection/data/add/Pitt-add-0.5-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 36388.53it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 35766.64it/s]
# []

# %%
RAW_WEIGHT = 1.0

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Demucs'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 35068.46it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 35191.70it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Denoiser'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 34276.22it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 36616.47it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-FRCRN_SE'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 59330.23it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 70268.92it/s]
# 跳过了 551 个文件:
#   - 086-1.wav: 降噪文件不存在
#   - 002-0.wav: 降噪文件不存在
#   - 086-2.wav: 降噪文件不存在
#   - 002-1.wav: 降噪文件不存在
#   - 086-3.wav: 降噪文件不存在
#   - 002-2.wav: 降噪文件不存在
#   - 086-4.wav: 降噪文件不存在
#   - 002-3.wav: 降噪文件不存在
#   - 092-1.wav: 降噪文件不存在
#   - 006-2.wav: 降噪文件不存在
#   ... 还有 541 个文件
# [('086-1.wav', '降噪文件不存在'),
#  ('002-0.wav', '降噪文件不存在'),
#  ('086-2.wav', '降噪文件不存在'),
#  ('002-1.wav', '降噪文件不存在'),
#  ('086-3.wav', '降噪文件不存在'),
#  ('002-2.wav', '降噪文件不存在'),
#  ('086-4.wav', '降噪文件不存在'),
#  ('002-3.wav', '降噪文件不存在'),
#  ('092-1.wav', '降噪文件不存在'),
#  ('006-2.wav', '降噪文件不存在'),
#  ('092-0.wav', '降噪文件不存在'),
#  ('006-3.wav', '降噪文件不存在'),
#  ('092-2.wav', '降噪文件不存在'),
#  ('006-4.wav', '降噪文件不存在'),
#  ('092-3.wav', '降噪文件不存在'),
#  ('013-0.wav', '降噪文件不存在'),
#  ('109-3.wav', '降噪文件不存在'),
#  ('013-2.wav', '降噪文件不存在'),
#  ('109-4.wav', '降噪文件不存在'),
#  ('013-3.wav', '降噪文件不存在'),
#  ('113-0.wav', '降噪文件不存在'),
#  ('013-4.wav', '降噪文件不存在'),
#  ('113-1.wav', '降噪文件不存在'),
#  ('015-0.wav', '降噪文件不存在'),
#  ('113-2.wav', '降噪文件不存在'),
#  ('015-1.wav', '降噪文件不存在'),
#  ('113-3.wav', '降噪文件不存在'),
#  ('015-2.wav', '降噪文件不存在'),
#  ('114-0.wav', '降噪文件不存在'),
#  ('015-3.wav', '降噪文件不存在'),
#  ('114-1.wav', '降噪文件不存在'),
#  ('015-4.wav', '降噪文件不存在'),
#  ('114-2.wav', '降噪文件不存在'),
#  ('017-4.wav', '降噪文件不存在'),
#  ('114-3.wav', '降噪文件不存在'),
#  ('021-0.wav', '降噪文件不存在'),
#  ('114-4.wav', '降噪文件不存在'),
#  ('021-1.wav', '降噪文件不存在'),
#  ('118-0.wav', '降噪文件不存在'),
#  ('021-2.wav', '降噪文件不存在'),
#  ('118-1.wav', '降噪文件不存在'),
#  ('021-3.wav', '降噪文件不存在'),
#  ('118-2.wav', '降噪文件不存在'),
#  ('021-4.wav', '降噪文件不存在'),
#  ('118-3.wav', '降噪文件不存在'),
#  ('022-0.wav', '降噪文件不存在'),
#  ('118-4.wav', '降噪文件不存在'),
#  ('022-1.wav', '降噪文件不存在'),
#  ('121-0.wav', '降噪文件不存在'),
#  ('022-2.wav', '降噪文件不存在'),
#  ('121-1.wav', '降噪文件不存在'),
#  ('028-1.wav', '降噪文件不存在'),
#  ('121-2.wav', '降噪文件不存在'),
#  ('028-4.wav', '降噪文件不存在'),
#  ('121-3.wav', '降噪文件不存在'),
#  ('034-0.wav', '降噪文件不存在'),
#  ('121-4.wav', '降噪文件不存在'),
#  ('034-1.wav', '降噪文件不存在'),
#  ('124-0.wav', '降噪文件不存在'),
#  ('034-2.wav', '降噪文件不存在'),
#  ('124-1.wav', '降噪文件不存在'),
#  ('034-3.wav', '降噪文件不存在'),
#  ('128-1.wav', '降噪文件不存在'),
#  ('034-4.wav', '降噪文件不存在'),
#  ('128-2.wav', '降噪文件不存在'),
#  ('042-1.wav', '降噪文件不存在'),
#  ('128-3.wav', '降噪文件不存在'),
#  ('042-2.wav', '降噪文件不存在'),
#  ('129-1.wav', '降噪文件不存在'),
#  ('042-3.wav', '降噪文件不存在'),
#  ('130-1.wav', '降噪文件不存在'),
#  ('042-4.wav', '降噪文件不存在'),
#  ('130-2.wav', '降噪文件不存在'),
#  ('045-0.wav', '降噪文件不存在'),
#  ('130-3.wav', '降噪文件不存在'),
#  ('045-2.wav', '降噪文件不存在'),
#  ('132-0.wav', '降噪文件不存在'),
#  ('045-3.wav', '降噪文件不存在'),
#  ('132-1.wav', '降噪文件不存在'),
#  ('052-0.wav', '降噪文件不存在'),
#  ('137-0.wav', '降噪文件不存在'),
#  ('052-2.wav', '降噪文件不存在'),
#  ('137-1.wav', '降噪文件不存在'),
#  ('054-0.wav', '降噪文件不存在'),
#  ('137-2.wav', '降噪文件不存在'),
#  ('055-0.wav', '降噪文件不存在'),
#  ('137-3.wav', '降噪文件不存在'),
#  ('056-0.wav', '降噪文件不存在'),
#  ('138-1.wav', '降噪文件不存在'),
#  ('056-3.wav', '降噪文件不存在'),
#  ('138-3.wav', '降噪文件不存在'),
#  ('056-4.wav', '降噪文件不存在'),
#  ('139-0.wav', '降噪文件不存在'),
#  ('059-2.wav', '降噪文件不存在'),
#  ('139-1.wav', '降噪文件不存在'),
#  ('059-3.wav', '降噪文件不存在'),
#  ('139-3.wav', '降噪文件不存在'),
#  ('059-4.wav', '降噪文件不存在'),
#  ('140-0.wav', '降噪文件不存在'),
#  ('068-0.wav', '降噪文件不存在'),
#  ('140-3.wav', '降噪文件不存在'),
#  ('068-2.wav', '降噪文件不存在'),
#  ('141-0.wav', '降噪文件不存在'),
#  ('068-3.wav', '降噪文件不存在'),
#  ('141-1.wav', '降噪文件不存在'),
#  ('071-0.wav', '降噪文件不存在'),
#  ('141-2.wav', '降噪文件不存在'),
#  ('071-1.wav', '降噪文件不存在'),
#  ('141-3.wav', '降噪文件不存在'),
#  ('071-2.wav', '降噪文件不存在'),
#  ('142-0.wav', '降噪文件不存在'),
#  ('071-3.wav', '降噪文件不存在'),
#  ('142-1.wav', '降噪文件不存在'),
#  ('071-4.wav', '降噪文件不存在'),
#  ('142-3.wav', '降噪文件不存在'),
#  ('073-0.wav', '降噪文件不存在'),
#  ('143-3.wav', '降噪文件不存在'),
#  ('073-1.wav', '降噪文件不存在'),
#  ('145-1.wav', '降噪文件不存在'),
#  ('073-3.wav', '降噪文件不存在'),
#  ('145-3.wav', '降噪文件不存在'),
#  ('086-0.wav', '降噪文件不存在'),
#  ('093-0.wav', '降噪文件不存在'),
#  ('146-1.wav', '降噪文件不存在'),
#  ('093-1.wav', '降噪文件不存在'),
#  ('150-0.wav', '降噪文件不存在'),
#  ('096-1.wav', '降噪文件不存在'),
#  ('150-1.wav', '降噪文件不存在'),
#  ('096-2.wav', '降噪文件不存在'),
#  ('150-2.wav', '降噪文件不存在'),
#  ('105-0.wav', '降噪文件不存在'),
#  ('155-0.wav', '降噪文件不存在'),
#  ('105-1.wav', '降噪文件不存在'),
#  ('155-2.wav', '降噪文件不存在'),
#  ('105-2.wav', '降噪文件不存在'),
#  ('155-3.wav', '降噪文件不存在'),
#  ('107-1.wav', '降噪文件不存在'),
#  ('158-0.wav', '降噪文件不存在'),
#  ('107-2.wav', '降噪文件不存在'),
#  ('158-1.wav', '降噪文件不存在'),
#  ('109-1.wav', '降噪文件不存在'),
#  ('158-2.wav', '降噪文件不存在'),
#  ('158-3.wav', '降噪文件不存在'),
#  ('166-0.wav', '降噪文件不存在'),
#  ('166-1.wav', '降噪文件不存在'),
#  ('166-2.wav', '降噪文件不存在'),
#  ('167-1.wav', '降噪文件不存在'),
#  ('167-2.wav', '降噪文件不存在'),
#  ('167-3.wav', '降噪文件不存在'),
#  ('171-0.wav', '降噪文件不存在'),
#  ('171-1.wav', '降噪文件不存在'),
#  ('172-0.wav', '降噪文件不存在'),
#  ('175-0.wav', '降噪文件不存在'),
#  ('175-1.wav', '降噪文件不存在'),
#  ('175-2.wav', '降噪文件不存在'),
#  ('175-3.wav', '降噪文件不存在'),
#  ('182-3.wav', '降噪文件不存在'),
#  ('192-0.wav', '降噪文件不存在'),
#  ('192-2.wav', '降噪文件不存在'),
#  ('196-0.wav', '降噪文件不存在'),
#  ('196-1.wav', '降噪文件不存在'),
#  ('208-0.wav', '降噪文件不存在'),
#  ('208-1.wav', '降噪文件不存在'),
#  ('208-2.wav', '降噪文件不存在'),
#  ('209-1.wav', '降噪文件不存在'),
#  ('209-2.wav', '降噪文件不存在'),
#  ('209-3.wav', '降噪文件不存在'),
#  ('210-1.wav', '降噪文件不存在'),
#  ('210-2.wav', '降噪文件不存在'),
#  ('211-1.wav', '降噪文件不存在'),
#  ('211-2.wav', '降噪文件不存在'),
#  ('225-0.wav', '降噪文件不存在'),
#  ('225-2.wav', '降噪文件不存在'),
#  ('227-0.wav', '降噪文件不存在'),
#  ('227-1.wav', '降噪文件不存在'),
#  ('229-1.wav', '降噪文件不存在'),
#  ('229-2.wav', '降噪文件不存在'),
#  ('232-0.wav', '降噪文件不存在'),
#  ('232-1.wav', '降噪文件不存在'),
#  ('242-0.wav', '降噪文件不存在'),
#  ('242-1.wav', '降噪文件不存在'),
#  ('242-2.wav', '降噪文件不存在'),
#  ('243-0.wav', '降噪文件不存在'),
#  ('243-1.wav', '降噪文件不存在'),
#  ('245-0.wav', '降噪文件不存在'),
#  ('245-1.wav', '降噪文件不存在'),
#  ('245-2.wav', '降噪文件不存在'),
#  ('248-0.wav', '降噪文件不存在'),
#  ('248-1.wav', '降噪文件不存在'),
#  ('248-2.wav', '降噪文件不存在'),
#  ('255-0.wav', '降噪文件不存在'),
#  ('255-1.wav', '降噪文件不存在'),
#  ('256-0.wav', '降噪文件不存在'),
#  ('256-1.wav', '降噪文件不存在'),
#  ('256-2.wav', '降噪文件不存在'),
#  ('266-0.wav', '降噪文件不存在'),
#  ('266-1.wav', '降噪文件不存在'),
#  ('266-2.wav', '降噪文件不存在'),
#  ('267-0.wav', '降噪文件不存在'),
#  ('267-2.wav', '降噪文件不存在'),
#  ('274-0.wav', '降噪文件不存在'),
#  ('274-1.wav', '降噪文件不存在'),
#  ('274-2.wav', '降噪文件不存在'),
#  ('275-0.wav', '降噪文件不存在'),
#  ('275-1.wav', '降噪文件不存在'),
#  ('280-0.wav', '降噪文件不存在'),
#  ('280-1.wav', '降噪文件不存在'),
#  ('280-2.wav', '降噪文件不存在'),
#  ('292-1.wav', '降噪文件不存在'),
#  ('295-0.wav', '降噪文件不存在'),
#  ('295-1.wav', '降噪文件不存在'),
#  ('296-0.wav', '降噪文件不存在'),
#  ('296-1.wav', '降噪文件不存在'),
#  ('296-2.wav', '降噪文件不存在'),
#  ('297-1.wav', '降噪文件不存在'),
#  ('297-2.wav', '降噪文件不存在'),
#  ('298-1.wav', '降噪文件不存在'),
#  ('299-1.wav', '降噪文件不存在'),
#  ('302-0.wav', '降噪文件不存在'),
#  ('304-2.wav', '降噪文件不存在'),
#  ('318-0.wav', '降噪文件不存在'),
#  ('318-1.wav', '降噪文件不存在'),
#  ('318-2.wav', '降噪文件不存在'),
#  ('322-1.wav', '降噪文件不存在'),
#  ('322-2.wav', '降噪文件不存在'),
#  ('323-0.wav', '降噪文件不存在'),
#  ('323-1.wav', '降噪文件不存在'),
#  ('332-0.wav', '降噪文件不存在'),
#  ('336-1.wav', '降噪文件不存在'),
#  ('340-0.wav', '降噪文件不存在'),
#  ('612-0.wav', '降噪文件不存在'),
#  ('627-0.wav', '降噪文件不存在'),
#  ('631-0.wav', '降噪文件不存在'),
#  ('661-0.wav', '降噪文件不存在'),
#  ('668-0.wav', '降噪文件不存在'),
#  ('678-0.wav', '降噪文件不存在'),
#  ('684-0.wav', '降噪文件不存在'),
#  ('686-0.wav', '降噪文件不存在'),
#  ('688-0.wav', '降噪文件不存在'),
#  ('691-0.wav', '降噪文件不存在'),
#  ('709-0.wav', '降噪文件不存在'),
#  ('709-2.wav', '降噪文件不存在'),
#  ('067-2.wav', '降噪文件不存在'),
#  ('001-0.wav', '降噪文件不存在'),
#  ('070-2.wav', '降噪文件不存在'),
#  ('001-2.wav', '降噪文件不存在'),
#  ('076-0.wav', '降噪文件不存在'),
#  ('003-0.wav', '降噪文件不存在'),
#  ('076-2.wav', '降噪文件不存在'),
#  ('005-0.wav', '降噪文件不存在'),
#  ('078-0.wav', '降噪文件不存在'),
#  ('005-2.wav', '降噪文件不存在'),
#  ('076-4.wav', '降噪文件不存在'),
#  ('007-1.wav', '降噪文件不存在'),
#  ('078-1.wav', '降噪文件不存在'),
#  ('007-3.wav', '降噪文件不存在'),
#  ('087-1.wav', '降噪文件不存在'),
#  ('010-0.wav', '降噪文件不存在'),
#  ('120-2.wav', '降噪文件不存在'),
#  ('010-1.wav', '降噪文件不存在'),
#  ('120-3.wav', '降噪文件不存在'),
#  ('010-2.wav', '降噪文件不存在'),
#  ('120-4.wav', '降噪文件不存在'),
#  ('010-3.wav', '降噪文件不存在'),
#  ('122-0.wav', '降噪文件不存在'),
#  ('010-4.wav', '降噪文件不存在'),
#  ('122-1.wav', '降噪文件不存在'),
#  ('014-2.wav', '降噪文件不存在'),
#  ('125-0.wav', '降噪文件不存在'),
#  ('016-0.wav', '降噪文件不存在'),
#  ('127-0.wav', '降噪文件不存在'),
#  ('016-1.wav', '降噪文件不存在'),
#  ('134-0.wav', '降噪文件不存在'),
#  ('016-3.wav', '降噪文件不存在'),
#  ('134-1.wav', '降噪文件不存在'),
#  ('016-4.wav', '降噪文件不存在'),
#  ('134-2.wav', '降噪文件不存在'),
#  ('018-0.wav', '降噪文件不存在'),
#  ('134-3.wav', '降噪文件不存在'),
#  ('023-0.wav', '降噪文件不存在'),
#  ('144-0.wav', '降噪文件不存在'),
#  ('023-2.wav', '降噪文件不存在'),
#  ('144-1.wav', '降噪文件不存在'),
#  ('024-1.wav', '降噪文件不存在'),
#  ('148-0.wav', '降噪文件不存在'),
#  ('024-2.wav', '降噪文件不存在'),
#  ('154-0.wav', '降噪文件不存在'),
#  ('029-0.wav', '降噪文件不存在'),
#  ('154-1.wav', '降噪文件不存在'),
#  ('029-1.wav', '降噪文件不存在'),
#  ('157-0.wav', '降噪文件不存在'),
#  ('030-0.wav', '降噪文件不存在'),
#  ('157-1.wav', '降噪文件不存在'),
#  ('030-1.wav', '降噪文件不存在'),
#  ('157-2.wav', '降噪文件不存在'),
#  ('033-0.wav', '降噪文件不存在'),
#  ('164-1.wav', '降噪文件不存在'),
#  ('033-1.wav', '降噪文件不存在'),
#  ('164-2.wav', '降噪文件不存在'),
#  ('033-2.wav', '降噪文件不存在'),
#  ('164-3.wav', '降噪文件不存在'),
#  ('033-3.wav', '降噪文件不存在'),
#  ('168-0.wav', '降噪文件不存在'),
#  ('033-4.wav', '降噪文件不存在'),
#  ('168-1.wav', '降噪文件不存在'),
#  ('035-0.wav', '降噪文件不存在'),
#  ('172-1.wav', '降噪文件不存在'),
#  ('035-1.wav', '降噪文件不存在'),
#  ('172-2.wav', '降噪文件不存在'),
#  ('039-0.wav', '降噪文件不存在'),
#  ('172-3.wav', '降噪文件不存在'),
#  ('043-0.wav', '降噪文件不存在'),
#  ('173-1.wav', '降噪文件不存在'),
#  ('046-0.wav', '降噪文件不存在'),
#  ('178-0.wav', '降噪文件不存在'),
#  ('046-2.wav', '降噪文件不存在'),
#  ('178-1.wav', '降噪文件不存在'),
#  ('049-0.wav', '降噪文件不存在'),
#  ('181-0.wav', '降噪文件不存在'),
#  ('049-1.wav', '降噪文件不存在'),
#  ('181-1.wav', '降噪文件不存在'),
#  ('050-0.wav', '降噪文件不存在'),
#  ('181-2.wav', '降噪文件不存在'),
#  ('051-0.wav', '降噪文件不存在'),
#  ('181-3.wav', '降噪文件不存在'),
#  ('051-1.wav', '降噪文件不存在'),
#  ('183-0.wav', '降噪文件不存在'),
#  ('051-2.wav', '降噪文件不存在'),
#  ('183-1.wav', '降噪文件不存在'),
#  ('051-3.wav', '降噪文件不存在'),
#  ('183-2.wav', '降噪文件不存在'),
#  ('053-1.wav', '降噪文件不存在'),
#  ('183-3.wav', '降噪文件不存在'),
#  ('057-0.wav', '降噪文件不存在'),
#  ('184-0.wav', '降噪文件不存在'),
#  ('057-1.wav', '降噪文件不存在'),
#  ('184-1.wav', '降噪文件不存在'),
#  ('057-2.wav', '降噪文件不存在'),
#  ('184-2.wav', '降噪文件不存在'),
#  ('058-0.wav', '降噪文件不存在'),
#  ('190-1.wav', '降噪文件不存在'),
#  ('058-1.wav', '降噪文件不存在'),
#  ('190-2.wav', '降噪文件不存在'),
#  ('058-3.wav', '降噪文件不存在'),
#  ('203-0.wav', '降噪文件不存在'),
#  ('058-4.wav', '降噪文件不存在'),
#  ('203-1.wav', '降噪文件不存在'),
#  ('061-0.wav', '降噪文件不存在'),
#  ('205-1.wav', '降噪文件不存在'),
#  ('061-1.wav', '降噪文件不存在'),
#  ('206-0.wav', '降噪文件不存在'),
#  ('062-0.wav', '降噪文件不存在'),
#  ('207-0.wav', '降噪文件不存在'),
#  ('062-3.wav', '降噪文件不存在'),
#  ('212-0.wav', '降噪文件不存在'),
#  ('065-0.wav', '降噪文件不存在'),
#  ('212-1.wav', '降噪文件不存在'),
#  ('065-1.wav', '降噪文件不存在'),
#  ('212-2.wav', '降噪文件不存在'),
#  ('065-2.wav', '降噪文件不存在'),
#  ('212-3.wav', '降噪文件不存在'),
#  ('066-0.wav', '降噪文件不存在'),
#  ('213-1.wav', '降噪文件不存在'),
#  ('067-1.wav', '降噪文件不存在'),
#  ('089-0.wav', '降噪文件不存在'),
#  ('213-2.wav', '降噪文件不存在'),
#  ('091-0.wav', '降噪文件不存在'),
#  ('213-3.wav', '降噪文件不存在'),
#  ('091-1.wav', '降噪文件不存在'),
#  ('216-0.wav', '降噪文件不存在'),
#  ('091-2.wav', '降噪文件不存在'),
#  ('216-1.wav', '降噪文件不存在'),
#  ('094-1.wav', '降噪文件不存在'),
#  ('218-0.wav', '降噪文件不存在'),
#  ('094-2.wav', '降噪文件不存在'),
#  ('218-1.wav', '降噪文件不存在'),
#  ('094-3.wav', '降噪文件不存在'),
#  ('220-0.wav', '降噪文件不存在'),
#  ('097-1.wav', '降噪文件不存在'),
#  ('220-1.wav', '降噪文件不存在'),
#  ('120-0.wav', '降噪文件不存在'),
#  ('221-0.wav', '降噪文件不存在'),
#  ('120-1.wav', '降噪文件不存在'),
#  ('221-1.wav', '降噪文件不存在'),
#  ('221-2.wav', '降噪文件不存在'),
#  ('221-3.wav', '降噪文件不存在'),
#  ('222-0.wav', '降噪文件不存在'),
#  ('222-1.wav', '降噪文件不存在'),
#  ('223-0.wav', '降噪文件不存在'),
#  ('223-1.wav', '降噪文件不存在'),
#  ('226-0.wav', '降噪文件不存在'),
#  ('234-0.wav', '降噪文件不存在'),
#  ('235-0.wav', '降噪文件不存在'),
#  ('235-2.wav', '降噪文件不存在'),
#  ('236-0.wav', '降噪文件不存在'),
#  ('237-1.wav', '降噪文件不存在'),
#  ('237-2.wav', '降噪文件不存在'),
#  ('238-0.wav', '降噪文件不存在'),
#  ('244-0.wav', '降噪文件不存在'),
#  ('247-0.wav', '降噪文件不存在'),
#  ('252-0.wav', '降噪文件不存在'),
#  ('252-1.wav', '降噪文件不存在'),
#  ('252-2.wav', '降噪文件不存在'),
#  ('257-0.wav', '降噪文件不存在'),
#  ('257-2.wav', '降噪文件不存在'),
#  ('260-1.wav', '降噪文件不存在'),
#  ('260-2.wav', '降噪文件不存在'),
#  ('264-0.wav', '降噪文件不存在'),
#  ('268-0.wav', '降噪文件不存在'),
#  ('269-0.wav', '降噪文件不存在'),
#  ('269-1.wav', '降噪文件不存在'),
#  ('270-0.wav', '降噪文件不存在'),
#  ('270-1.wav', '降噪文件不存在'),
#  ('270-2.wav', '降噪文件不存在'),
#  ('271-2.wav', '降噪文件不存在'),
#  ('276-0.wav', '降噪文件不存在'),
#  ('279-0.wav', '降噪文件不存在'),
#  ('279-1.wav', '降噪文件不存在'),
#  ('282-0.wav', '降噪文件不存在'),
#  ('282-1.wav', '降噪文件不存在'),
#  ('282-2.wav', '降噪文件不存在'),
#  ('283-0.wav', '降噪文件不存在'),
#  ('283-1.wav', '降噪文件不存在'),
#  ('289-2.wav', '降噪文件不存在'),
#  ('291-1.wav', '降噪文件不存在'),
#  ('291-2.wav', '降噪文件不存在'),
#  ('293-1.wav', '降噪文件不存在'),
#  ('306-0.wav', '降噪文件不存在'),
#  ('310-0.wav', '降噪文件不存在'),
#  ('311-0.wav', '降噪文件不存在'),
#  ('319-0.wav', '降噪文件不存在'),
#  ('325-0.wav', '降噪文件不存在'),
#  ('325-1.wav', '降噪文件不存在'),
#  ('329-0.wav', '降噪文件不存在'),
#  ('334-0.wav', '降噪文件不存在'),
#  ('334-1.wav', '降噪文件不存在'),
#  ('337-0.wav', '降噪文件不存在'),
#  ('338-0.wav', '降噪文件不存在'),
#  ('339-0.wav', '降噪文件不存在'),
#  ('341-0.wav', '降噪文件不存在'),
#  ('342-0.wav', '降噪文件不存在'),
#  ('342-1.wav', '降噪文件不存在'),
#  ('343-0.wav', '降噪文件不存在'),
#  ('344-0.wav', '降噪文件不存在'),
#  ('344-2.wav', '降噪文件不存在'),
#  ('346-0.wav', '降噪文件不存在'),
#  ('349-0.wav', '降噪文件不存在'),
#  ('349-1.wav', '降噪文件不存在'),
#  ('350-0.wav', '降噪文件不存在'),
#  ('350-1.wav', '降噪文件不存在'),
#  ('354-0.wav', '降噪文件不存在'),
#  ('355-0.wav', '降噪文件不存在'),
#  ('355-1.wav', '降噪文件不存在'),
#  ('356-0.wav', '降噪文件不存在'),
#  ('356-1.wav', '降噪文件不存在'),
#  ('357-0.wav', '降噪文件不存在'),
#  ('358-0.wav', '降噪文件不存在'),
#  ('358-1.wav', '降噪文件不存在'),
#  ('360-0.wav', '降噪文件不存在'),
#  ('361-0.wav', '降噪文件不存在'),
#  ('362-0.wav', '降噪文件不存在'),
#  ('362-1.wav', '降噪文件不存在'),
#  ('368-0.wav', '降噪文件不存在'),
#  ('369-0.wav', '降噪文件不存在'),
#  ('381-0.wav', '降噪文件不存在'),
#  ('381-1.wav', '降噪文件不存在'),
#  ('450-0.wav', '降噪文件不存在'),
#  ('450-1.wav', '降噪文件不存在'),
#  ('458-0.wav', '降噪文件不存在'),
#  ('461-0.wav', '降噪文件不存在'),
#  ('465-0.wav', '降噪文件不存在'),
#  ('466-0.wav', '降噪文件不存在'),
#  ('466-1.wav', '降噪文件不存在'),
#  ('468-0.wav', '降噪文件不存在'),
#  ('470-1.wav', '降噪文件不存在'),
#  ('471-0.wav', '降噪文件不存在'),
#  ('472-0.wav', '降噪文件不存在'),
#  ('474-0.wav', '降噪文件不存在'),
#  ('476-0.wav', '降噪文件不存在'),
#  ('488-0.wav', '降噪文件不存在'),
#  ('488-1.wav', '降噪文件不存在'),
#  ('492-0.wav', '降噪文件不存在'),
#  ('493-0.wav', '降噪文件不存在'),
#  ('493-1.wav', '降噪文件不存在'),
#  ('497-0.wav', '降噪文件不存在'),
#  ('497-1.wav', '降噪文件不存在'),
#  ('504-0.wav', '降噪文件不存在'),
#  ('506-0.wav', '降噪文件不存在'),
#  ('508-0.wav', '降噪文件不存在'),
#  ('508-1.wav', '降噪文件不存在'),
#  ('511-0.wav', '降噪文件不存在'),
#  ('515-1.wav', '降噪文件不存在'),
#  ('526-1.wav', '降噪文件不存在'),
#  ('527-0.wav', '降噪文件不存在'),
#  ('527-1.wav', '降噪文件不存在'),
#  ('528-0.wav', '降噪文件不存在'),
#  ('529-0.wav', '降噪文件不存在'),
#  ('530-0.wav', '降噪文件不存在'),
#  ('539-0.wav', '降噪文件不存在'),
#  ('544-0.wav', '降噪文件不存在'),
#  ('544-1.wav', '降噪文件不存在'),
#  ('551-0.wav', '降噪文件不存在'),
#  ('559-0.wav', '降噪文件不存在'),
#  ('562-0.wav', '降噪文件不存在'),
#  ('563-0.wav', '降噪文件不存在'),
#  ('573-0.wav', '降噪文件不存在'),
#  ('578-0.wav', '降噪文件不存在'),
#  ('579-0.wav', '降噪文件不存在'),
#  ('580-0.wav', '降噪文件不存在'),
#  ('581-0.wav', '降噪文件不存在'),
#  ('585-0.wav', '降噪文件不存在'),
#  ('587-0.wav', '降噪文件不存在'),
#  ('591-0.wav', '降噪文件不存在'),
#  ('592-0.wav', '降噪文件不存在'),
#  ('594-0.wav', '降噪文件不存在'),
#  ('595-0.wav', '降噪文件不存在'),
#  ('598-0.wav', '降噪文件不存在'),
#  ('601-0.wav', '降噪文件不存在'),
#  ('607-0.wav', '降噪文件不存在'),
#  ('609-0.wav', '降噪文件不存在'),
#  ('610-0.wav', '降噪文件不存在'),
#  ('615-0.wav', '降噪文件不存在'),
#  ('620-0.wav', '降噪文件不存在'),
#  ('624-0.wav', '降噪文件不存在'),
#  ('635-0.wav', '降噪文件不存在'),
#  ('636-0.wav', '降噪文件不存在'),
#  ('639-0.wav', '降噪文件不存在'),
#  ('640-0.wav', '降噪文件不存在'),
#  ('642-0.wav', '降噪文件不存在'),
#  ('648-0.wav', '降噪文件不存在'),
#  ('650-0.wav', '降噪文件不存在'),
#  ('651-0.wav', '降噪文件不存在'),
#  ('656-0.wav', '降噪文件不存在'),
#  ('657-0.wav', '降噪文件不存在'),
#  ('660-0.wav', '降噪文件不存在'),
#  ('663-0.wav', '降噪文件不存在'),
#  ('672-0.wav', '降噪文件不存在'),
#  ('674-0.wav', '降噪文件不存在'),
#  ('676-0.wav', '降噪文件不存在'),
#  ('681-0.wav', '降噪文件不存在'),
#  ('689-0.wav', '降噪文件不存在'),
#  ('690-0.wav', '降噪文件不存在'),
#  ('695-0.wav', '降噪文件不存在'),
#  ('698-0.wav', '降噪文件不存在'),
#  ('702-0.wav', '降噪文件不存在'),
#  ('703-0.wav', '降噪文件不存在'),
#  ('704-0.wav', '降噪文件不存在'),
#  ('705-0.wav', '降噪文件不存在'),
#  ('707-0.wav', '降噪文件不存在'),
#  ('711-0.wav', '降噪文件不存在'),
#  ('714-0.wav', '降噪文件不存在')]

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-MossFormer'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 35420.91it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 35439.98it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Resemble'
output_dir = '../ad_detection/data/add/Pitt-add-1.0-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 34938.10it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 35806.16it/s]
# []

# %%
RAW_WEIGHT = 1.5

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Demucs'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 33268.49it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 35031.89it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Denoiser'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 35659.84it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 36127.56it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-FRCRN_SE'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 58780.49it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 62294.64it/s]
# 跳过了 551 个文件:
#   - 086-1.wav: 降噪文件不存在
#   - 002-0.wav: 降噪文件不存在
#   - 086-2.wav: 降噪文件不存在
#   - 002-1.wav: 降噪文件不存在
#   - 086-3.wav: 降噪文件不存在
#   - 002-2.wav: 降噪文件不存在
#   - 086-4.wav: 降噪文件不存在
#   - 002-3.wav: 降噪文件不存在
#   - 092-1.wav: 降噪文件不存在
#   - 006-2.wav: 降噪文件不存在
#   ... 还有 541 个文件
# [('086-1.wav', '降噪文件不存在'),
#  ('002-0.wav', '降噪文件不存在'),
#  ('086-2.wav', '降噪文件不存在'),
#  ('002-1.wav', '降噪文件不存在'),
#  ('086-3.wav', '降噪文件不存在'),
#  ('002-2.wav', '降噪文件不存在'),
#  ('086-4.wav', '降噪文件不存在'),
#  ('002-3.wav', '降噪文件不存在'),
#  ('092-1.wav', '降噪文件不存在'),
#  ('006-2.wav', '降噪文件不存在'),
#  ('092-0.wav', '降噪文件不存在'),
#  ('006-3.wav', '降噪文件不存在'),
#  ('092-2.wav', '降噪文件不存在'),
#  ('006-4.wav', '降噪文件不存在'),
#  ('092-3.wav', '降噪文件不存在'),
#  ('013-0.wav', '降噪文件不存在'),
#  ('109-3.wav', '降噪文件不存在'),
#  ('013-2.wav', '降噪文件不存在'),
#  ('109-4.wav', '降噪文件不存在'),
#  ('013-3.wav', '降噪文件不存在'),
#  ('113-0.wav', '降噪文件不存在'),
#  ('013-4.wav', '降噪文件不存在'),
#  ('113-1.wav', '降噪文件不存在'),
#  ('015-0.wav', '降噪文件不存在'),
#  ('113-2.wav', '降噪文件不存在'),
#  ('015-1.wav', '降噪文件不存在'),
#  ('113-3.wav', '降噪文件不存在'),
#  ('015-2.wav', '降噪文件不存在'),
#  ('114-0.wav', '降噪文件不存在'),
#  ('015-3.wav', '降噪文件不存在'),
#  ('114-1.wav', '降噪文件不存在'),
#  ('015-4.wav', '降噪文件不存在'),
#  ('114-2.wav', '降噪文件不存在'),
#  ('017-4.wav', '降噪文件不存在'),
#  ('114-3.wav', '降噪文件不存在'),
#  ('021-0.wav', '降噪文件不存在'),
#  ('114-4.wav', '降噪文件不存在'),
#  ('021-1.wav', '降噪文件不存在'),
#  ('118-0.wav', '降噪文件不存在'),
#  ('021-2.wav', '降噪文件不存在'),
#  ('118-1.wav', '降噪文件不存在'),
#  ('021-3.wav', '降噪文件不存在'),
#  ('118-2.wav', '降噪文件不存在'),
#  ('021-4.wav', '降噪文件不存在'),
#  ('118-3.wav', '降噪文件不存在'),
#  ('022-0.wav', '降噪文件不存在'),
#  ('118-4.wav', '降噪文件不存在'),
#  ('022-1.wav', '降噪文件不存在'),
#  ('121-0.wav', '降噪文件不存在'),
#  ('022-2.wav', '降噪文件不存在'),
#  ('121-1.wav', '降噪文件不存在'),
#  ('028-1.wav', '降噪文件不存在'),
#  ('121-2.wav', '降噪文件不存在'),
#  ('028-4.wav', '降噪文件不存在'),
#  ('121-3.wav', '降噪文件不存在'),
#  ('034-0.wav', '降噪文件不存在'),
#  ('121-4.wav', '降噪文件不存在'),
#  ('034-1.wav', '降噪文件不存在'),
#  ('124-0.wav', '降噪文件不存在'),
#  ('034-2.wav', '降噪文件不存在'),
#  ('124-1.wav', '降噪文件不存在'),
#  ('034-3.wav', '降噪文件不存在'),
#  ('128-1.wav', '降噪文件不存在'),
#  ('034-4.wav', '降噪文件不存在'),
#  ('128-2.wav', '降噪文件不存在'),
#  ('042-1.wav', '降噪文件不存在'),
#  ('128-3.wav', '降噪文件不存在'),
#  ('042-2.wav', '降噪文件不存在'),
#  ('129-1.wav', '降噪文件不存在'),
#  ('042-3.wav', '降噪文件不存在'),
#  ('130-1.wav', '降噪文件不存在'),
#  ('042-4.wav', '降噪文件不存在'),
#  ('130-2.wav', '降噪文件不存在'),
#  ('045-0.wav', '降噪文件不存在'),
#  ('130-3.wav', '降噪文件不存在'),
#  ('045-2.wav', '降噪文件不存在'),
#  ('132-0.wav', '降噪文件不存在'),
#  ('045-3.wav', '降噪文件不存在'),
#  ('132-1.wav', '降噪文件不存在'),
#  ('052-0.wav', '降噪文件不存在'),
#  ('137-0.wav', '降噪文件不存在'),
#  ('052-2.wav', '降噪文件不存在'),
#  ('137-1.wav', '降噪文件不存在'),
#  ('054-0.wav', '降噪文件不存在'),
#  ('137-2.wav', '降噪文件不存在'),
#  ('055-0.wav', '降噪文件不存在'),
#  ('137-3.wav', '降噪文件不存在'),
#  ('056-0.wav', '降噪文件不存在'),
#  ('138-1.wav', '降噪文件不存在'),
#  ('056-3.wav', '降噪文件不存在'),
#  ('138-3.wav', '降噪文件不存在'),
#  ('056-4.wav', '降噪文件不存在'),
#  ('139-0.wav', '降噪文件不存在'),
#  ('059-2.wav', '降噪文件不存在'),
#  ('139-1.wav', '降噪文件不存在'),
#  ('059-3.wav', '降噪文件不存在'),
#  ('139-3.wav', '降噪文件不存在'),
#  ('059-4.wav', '降噪文件不存在'),
#  ('140-0.wav', '降噪文件不存在'),
#  ('068-0.wav', '降噪文件不存在'),
#  ('140-3.wav', '降噪文件不存在'),
#  ('068-2.wav', '降噪文件不存在'),
#  ('141-0.wav', '降噪文件不存在'),
#  ('068-3.wav', '降噪文件不存在'),
#  ('141-1.wav', '降噪文件不存在'),
#  ('071-0.wav', '降噪文件不存在'),
#  ('141-2.wav', '降噪文件不存在'),
#  ('071-1.wav', '降噪文件不存在'),
#  ('141-3.wav', '降噪文件不存在'),
#  ('071-2.wav', '降噪文件不存在'),
#  ('142-0.wav', '降噪文件不存在'),
#  ('071-3.wav', '降噪文件不存在'),
#  ('142-1.wav', '降噪文件不存在'),
#  ('071-4.wav', '降噪文件不存在'),
#  ('142-3.wav', '降噪文件不存在'),
#  ('073-0.wav', '降噪文件不存在'),
#  ('143-3.wav', '降噪文件不存在'),
#  ('073-1.wav', '降噪文件不存在'),
#  ('145-1.wav', '降噪文件不存在'),
#  ('073-3.wav', '降噪文件不存在'),
#  ('145-3.wav', '降噪文件不存在'),
#  ('086-0.wav', '降噪文件不存在'),
#  ('093-0.wav', '降噪文件不存在'),
#  ('146-1.wav', '降噪文件不存在'),
#  ('093-1.wav', '降噪文件不存在'),
#  ('150-0.wav', '降噪文件不存在'),
#  ('096-1.wav', '降噪文件不存在'),
#  ('150-1.wav', '降噪文件不存在'),
#  ('096-2.wav', '降噪文件不存在'),
#  ('150-2.wav', '降噪文件不存在'),
#  ('105-0.wav', '降噪文件不存在'),
#  ('155-0.wav', '降噪文件不存在'),
#  ('105-1.wav', '降噪文件不存在'),
#  ('155-2.wav', '降噪文件不存在'),
#  ('105-2.wav', '降噪文件不存在'),
#  ('155-3.wav', '降噪文件不存在'),
#  ('107-1.wav', '降噪文件不存在'),
#  ('158-0.wav', '降噪文件不存在'),
#  ('107-2.wav', '降噪文件不存在'),
#  ('158-1.wav', '降噪文件不存在'),
#  ('109-1.wav', '降噪文件不存在'),
#  ('158-2.wav', '降噪文件不存在'),
#  ('158-3.wav', '降噪文件不存在'),
#  ('166-0.wav', '降噪文件不存在'),
#  ('166-1.wav', '降噪文件不存在'),
#  ('166-2.wav', '降噪文件不存在'),
#  ('167-1.wav', '降噪文件不存在'),
#  ('167-2.wav', '降噪文件不存在'),
#  ('167-3.wav', '降噪文件不存在'),
#  ('171-0.wav', '降噪文件不存在'),
#  ('171-1.wav', '降噪文件不存在'),
#  ('172-0.wav', '降噪文件不存在'),
#  ('175-0.wav', '降噪文件不存在'),
#  ('175-1.wav', '降噪文件不存在'),
#  ('175-2.wav', '降噪文件不存在'),
#  ('175-3.wav', '降噪文件不存在'),
#  ('182-3.wav', '降噪文件不存在'),
#  ('192-0.wav', '降噪文件不存在'),
#  ('192-2.wav', '降噪文件不存在'),
#  ('196-0.wav', '降噪文件不存在'),
#  ('196-1.wav', '降噪文件不存在'),
#  ('208-0.wav', '降噪文件不存在'),
#  ('208-1.wav', '降噪文件不存在'),
#  ('208-2.wav', '降噪文件不存在'),
#  ('209-1.wav', '降噪文件不存在'),
#  ('209-2.wav', '降噪文件不存在'),
#  ('209-3.wav', '降噪文件不存在'),
#  ('210-1.wav', '降噪文件不存在'),
#  ('210-2.wav', '降噪文件不存在'),
#  ('211-1.wav', '降噪文件不存在'),
#  ('211-2.wav', '降噪文件不存在'),
#  ('225-0.wav', '降噪文件不存在'),
#  ('225-2.wav', '降噪文件不存在'),
#  ('227-0.wav', '降噪文件不存在'),
#  ('227-1.wav', '降噪文件不存在'),
#  ('229-1.wav', '降噪文件不存在'),
#  ('229-2.wav', '降噪文件不存在'),
#  ('232-0.wav', '降噪文件不存在'),
#  ('232-1.wav', '降噪文件不存在'),
#  ('242-0.wav', '降噪文件不存在'),
#  ('242-1.wav', '降噪文件不存在'),
#  ('242-2.wav', '降噪文件不存在'),
#  ('243-0.wav', '降噪文件不存在'),
#  ('243-1.wav', '降噪文件不存在'),
#  ('245-0.wav', '降噪文件不存在'),
#  ('245-1.wav', '降噪文件不存在'),
#  ('245-2.wav', '降噪文件不存在'),
#  ('248-0.wav', '降噪文件不存在'),
#  ('248-1.wav', '降噪文件不存在'),
#  ('248-2.wav', '降噪文件不存在'),
#  ('255-0.wav', '降噪文件不存在'),
#  ('255-1.wav', '降噪文件不存在'),
#  ('256-0.wav', '降噪文件不存在'),
#  ('256-1.wav', '降噪文件不存在'),
#  ('256-2.wav', '降噪文件不存在'),
#  ('266-0.wav', '降噪文件不存在'),
#  ('266-1.wav', '降噪文件不存在'),
#  ('266-2.wav', '降噪文件不存在'),
#  ('267-0.wav', '降噪文件不存在'),
#  ('267-2.wav', '降噪文件不存在'),
#  ('274-0.wav', '降噪文件不存在'),
#  ('274-1.wav', '降噪文件不存在'),
#  ('274-2.wav', '降噪文件不存在'),
#  ('275-0.wav', '降噪文件不存在'),
#  ('275-1.wav', '降噪文件不存在'),
#  ('280-0.wav', '降噪文件不存在'),
#  ('280-1.wav', '降噪文件不存在'),
#  ('280-2.wav', '降噪文件不存在'),
#  ('292-1.wav', '降噪文件不存在'),
#  ('295-0.wav', '降噪文件不存在'),
#  ('295-1.wav', '降噪文件不存在'),
#  ('296-0.wav', '降噪文件不存在'),
#  ('296-1.wav', '降噪文件不存在'),
#  ('296-2.wav', '降噪文件不存在'),
#  ('297-1.wav', '降噪文件不存在'),
#  ('297-2.wav', '降噪文件不存在'),
#  ('298-1.wav', '降噪文件不存在'),
#  ('299-1.wav', '降噪文件不存在'),
#  ('302-0.wav', '降噪文件不存在'),
#  ('304-2.wav', '降噪文件不存在'),
#  ('318-0.wav', '降噪文件不存在'),
#  ('318-1.wav', '降噪文件不存在'),
#  ('318-2.wav', '降噪文件不存在'),
#  ('322-1.wav', '降噪文件不存在'),
#  ('322-2.wav', '降噪文件不存在'),
#  ('323-0.wav', '降噪文件不存在'),
#  ('323-1.wav', '降噪文件不存在'),
#  ('332-0.wav', '降噪文件不存在'),
#  ('336-1.wav', '降噪文件不存在'),
#  ('340-0.wav', '降噪文件不存在'),
#  ('612-0.wav', '降噪文件不存在'),
#  ('627-0.wav', '降噪文件不存在'),
#  ('631-0.wav', '降噪文件不存在'),
#  ('661-0.wav', '降噪文件不存在'),
#  ('668-0.wav', '降噪文件不存在'),
#  ('678-0.wav', '降噪文件不存在'),
#  ('684-0.wav', '降噪文件不存在'),
#  ('686-0.wav', '降噪文件不存在'),
#  ('688-0.wav', '降噪文件不存在'),
#  ('691-0.wav', '降噪文件不存在'),
#  ('709-0.wav', '降噪文件不存在'),
#  ('709-2.wav', '降噪文件不存在'),
#  ('067-2.wav', '降噪文件不存在'),
#  ('001-0.wav', '降噪文件不存在'),
#  ('070-2.wav', '降噪文件不存在'),
#  ('001-2.wav', '降噪文件不存在'),
#  ('076-0.wav', '降噪文件不存在'),
#  ('003-0.wav', '降噪文件不存在'),
#  ('076-2.wav', '降噪文件不存在'),
#  ('005-0.wav', '降噪文件不存在'),
#  ('078-0.wav', '降噪文件不存在'),
#  ('005-2.wav', '降噪文件不存在'),
#  ('076-4.wav', '降噪文件不存在'),
#  ('007-1.wav', '降噪文件不存在'),
#  ('078-1.wav', '降噪文件不存在'),
#  ('007-3.wav', '降噪文件不存在'),
#  ('087-1.wav', '降噪文件不存在'),
#  ('010-0.wav', '降噪文件不存在'),
#  ('120-2.wav', '降噪文件不存在'),
#  ('010-1.wav', '降噪文件不存在'),
#  ('120-3.wav', '降噪文件不存在'),
#  ('010-2.wav', '降噪文件不存在'),
#  ('120-4.wav', '降噪文件不存在'),
#  ('010-3.wav', '降噪文件不存在'),
#  ('122-0.wav', '降噪文件不存在'),
#  ('010-4.wav', '降噪文件不存在'),
#  ('122-1.wav', '降噪文件不存在'),
#  ('014-2.wav', '降噪文件不存在'),
#  ('125-0.wav', '降噪文件不存在'),
#  ('016-0.wav', '降噪文件不存在'),
#  ('127-0.wav', '降噪文件不存在'),
#  ('016-1.wav', '降噪文件不存在'),
#  ('134-0.wav', '降噪文件不存在'),
#  ('016-3.wav', '降噪文件不存在'),
#  ('134-1.wav', '降噪文件不存在'),
#  ('016-4.wav', '降噪文件不存在'),
#  ('134-2.wav', '降噪文件不存在'),
#  ('018-0.wav', '降噪文件不存在'),
#  ('134-3.wav', '降噪文件不存在'),
#  ('023-0.wav', '降噪文件不存在'),
#  ('144-0.wav', '降噪文件不存在'),
#  ('023-2.wav', '降噪文件不存在'),
#  ('144-1.wav', '降噪文件不存在'),
#  ('024-1.wav', '降噪文件不存在'),
#  ('148-0.wav', '降噪文件不存在'),
#  ('024-2.wav', '降噪文件不存在'),
#  ('154-0.wav', '降噪文件不存在'),
#  ('029-0.wav', '降噪文件不存在'),
#  ('154-1.wav', '降噪文件不存在'),
#  ('029-1.wav', '降噪文件不存在'),
#  ('157-0.wav', '降噪文件不存在'),
#  ('030-0.wav', '降噪文件不存在'),
#  ('157-1.wav', '降噪文件不存在'),
#  ('030-1.wav', '降噪文件不存在'),
#  ('157-2.wav', '降噪文件不存在'),
#  ('033-0.wav', '降噪文件不存在'),
#  ('164-1.wav', '降噪文件不存在'),
#  ('033-1.wav', '降噪文件不存在'),
#  ('164-2.wav', '降噪文件不存在'),
#  ('033-2.wav', '降噪文件不存在'),
#  ('164-3.wav', '降噪文件不存在'),
#  ('033-3.wav', '降噪文件不存在'),
#  ('168-0.wav', '降噪文件不存在'),
#  ('033-4.wav', '降噪文件不存在'),
#  ('168-1.wav', '降噪文件不存在'),
#  ('035-0.wav', '降噪文件不存在'),
#  ('172-1.wav', '降噪文件不存在'),
#  ('035-1.wav', '降噪文件不存在'),
#  ('172-2.wav', '降噪文件不存在'),
#  ('039-0.wav', '降噪文件不存在'),
#  ('172-3.wav', '降噪文件不存在'),
#  ('043-0.wav', '降噪文件不存在'),
#  ('173-1.wav', '降噪文件不存在'),
#  ('046-0.wav', '降噪文件不存在'),
#  ('178-0.wav', '降噪文件不存在'),
#  ('046-2.wav', '降噪文件不存在'),
#  ('178-1.wav', '降噪文件不存在'),
#  ('049-0.wav', '降噪文件不存在'),
#  ('181-0.wav', '降噪文件不存在'),
#  ('049-1.wav', '降噪文件不存在'),
#  ('181-1.wav', '降噪文件不存在'),
#  ('050-0.wav', '降噪文件不存在'),
#  ('181-2.wav', '降噪文件不存在'),
#  ('051-0.wav', '降噪文件不存在'),
#  ('181-3.wav', '降噪文件不存在'),
#  ('051-1.wav', '降噪文件不存在'),
#  ('183-0.wav', '降噪文件不存在'),
#  ('051-2.wav', '降噪文件不存在'),
#  ('183-1.wav', '降噪文件不存在'),
#  ('051-3.wav', '降噪文件不存在'),
#  ('183-2.wav', '降噪文件不存在'),
#  ('053-1.wav', '降噪文件不存在'),
#  ('183-3.wav', '降噪文件不存在'),
#  ('057-0.wav', '降噪文件不存在'),
#  ('184-0.wav', '降噪文件不存在'),
#  ('057-1.wav', '降噪文件不存在'),
#  ('184-1.wav', '降噪文件不存在'),
#  ('057-2.wav', '降噪文件不存在'),
#  ('184-2.wav', '降噪文件不存在'),
#  ('058-0.wav', '降噪文件不存在'),
#  ('190-1.wav', '降噪文件不存在'),
#  ('058-1.wav', '降噪文件不存在'),
#  ('190-2.wav', '降噪文件不存在'),
#  ('058-3.wav', '降噪文件不存在'),
#  ('203-0.wav', '降噪文件不存在'),
#  ('058-4.wav', '降噪文件不存在'),
#  ('203-1.wav', '降噪文件不存在'),
#  ('061-0.wav', '降噪文件不存在'),
#  ('205-1.wav', '降噪文件不存在'),
#  ('061-1.wav', '降噪文件不存在'),
#  ('206-0.wav', '降噪文件不存在'),
#  ('062-0.wav', '降噪文件不存在'),
#  ('207-0.wav', '降噪文件不存在'),
#  ('062-3.wav', '降噪文件不存在'),
#  ('212-0.wav', '降噪文件不存在'),
#  ('065-0.wav', '降噪文件不存在'),
#  ('212-1.wav', '降噪文件不存在'),
#  ('065-1.wav', '降噪文件不存在'),
#  ('212-2.wav', '降噪文件不存在'),
#  ('065-2.wav', '降噪文件不存在'),
#  ('212-3.wav', '降噪文件不存在'),
#  ('066-0.wav', '降噪文件不存在'),
#  ('213-1.wav', '降噪文件不存在'),
#  ('067-1.wav', '降噪文件不存在'),
#  ('089-0.wav', '降噪文件不存在'),
#  ('213-2.wav', '降噪文件不存在'),
#  ('091-0.wav', '降噪文件不存在'),
#  ('213-3.wav', '降噪文件不存在'),
#  ('091-1.wav', '降噪文件不存在'),
#  ('216-0.wav', '降噪文件不存在'),
#  ('091-2.wav', '降噪文件不存在'),
#  ('216-1.wav', '降噪文件不存在'),
#  ('094-1.wav', '降噪文件不存在'),
#  ('218-0.wav', '降噪文件不存在'),
#  ('094-2.wav', '降噪文件不存在'),
#  ('218-1.wav', '降噪文件不存在'),
#  ('094-3.wav', '降噪文件不存在'),
#  ('220-0.wav', '降噪文件不存在'),
#  ('097-1.wav', '降噪文件不存在'),
#  ('220-1.wav', '降噪文件不存在'),
#  ('120-0.wav', '降噪文件不存在'),
#  ('221-0.wav', '降噪文件不存在'),
#  ('120-1.wav', '降噪文件不存在'),
#  ('221-1.wav', '降噪文件不存在'),
#  ('221-2.wav', '降噪文件不存在'),
#  ('221-3.wav', '降噪文件不存在'),
#  ('222-0.wav', '降噪文件不存在'),
#  ('222-1.wav', '降噪文件不存在'),
#  ('223-0.wav', '降噪文件不存在'),
#  ('223-1.wav', '降噪文件不存在'),
#  ('226-0.wav', '降噪文件不存在'),
#  ('234-0.wav', '降噪文件不存在'),
#  ('235-0.wav', '降噪文件不存在'),
#  ('235-2.wav', '降噪文件不存在'),
#  ('236-0.wav', '降噪文件不存在'),
#  ('237-1.wav', '降噪文件不存在'),
#  ('237-2.wav', '降噪文件不存在'),
#  ('238-0.wav', '降噪文件不存在'),
#  ('244-0.wav', '降噪文件不存在'),
#  ('247-0.wav', '降噪文件不存在'),
#  ('252-0.wav', '降噪文件不存在'),
#  ('252-1.wav', '降噪文件不存在'),
#  ('252-2.wav', '降噪文件不存在'),
#  ('257-0.wav', '降噪文件不存在'),
#  ('257-2.wav', '降噪文件不存在'),
#  ('260-1.wav', '降噪文件不存在'),
#  ('260-2.wav', '降噪文件不存在'),
#  ('264-0.wav', '降噪文件不存在'),
#  ('268-0.wav', '降噪文件不存在'),
#  ('269-0.wav', '降噪文件不存在'),
#  ('269-1.wav', '降噪文件不存在'),
#  ('270-0.wav', '降噪文件不存在'),
#  ('270-1.wav', '降噪文件不存在'),
#  ('270-2.wav', '降噪文件不存在'),
#  ('271-2.wav', '降噪文件不存在'),
#  ('276-0.wav', '降噪文件不存在'),
#  ('279-0.wav', '降噪文件不存在'),
#  ('279-1.wav', '降噪文件不存在'),
#  ('282-0.wav', '降噪文件不存在'),
#  ('282-1.wav', '降噪文件不存在'),
#  ('282-2.wav', '降噪文件不存在'),
#  ('283-0.wav', '降噪文件不存在'),
#  ('283-1.wav', '降噪文件不存在'),
#  ('289-2.wav', '降噪文件不存在'),
#  ('291-1.wav', '降噪文件不存在'),
#  ('291-2.wav', '降噪文件不存在'),
#  ('293-1.wav', '降噪文件不存在'),
#  ('306-0.wav', '降噪文件不存在'),
#  ('310-0.wav', '降噪文件不存在'),
#  ('311-0.wav', '降噪文件不存在'),
#  ('319-0.wav', '降噪文件不存在'),
#  ('325-0.wav', '降噪文件不存在'),
#  ('325-1.wav', '降噪文件不存在'),
#  ('329-0.wav', '降噪文件不存在'),
#  ('334-0.wav', '降噪文件不存在'),
#  ('334-1.wav', '降噪文件不存在'),
#  ('337-0.wav', '降噪文件不存在'),
#  ('338-0.wav', '降噪文件不存在'),
#  ('339-0.wav', '降噪文件不存在'),
#  ('341-0.wav', '降噪文件不存在'),
#  ('342-0.wav', '降噪文件不存在'),
#  ('342-1.wav', '降噪文件不存在'),
#  ('343-0.wav', '降噪文件不存在'),
#  ('344-0.wav', '降噪文件不存在'),
#  ('344-2.wav', '降噪文件不存在'),
#  ('346-0.wav', '降噪文件不存在'),
#  ('349-0.wav', '降噪文件不存在'),
#  ('349-1.wav', '降噪文件不存在'),
#  ('350-0.wav', '降噪文件不存在'),
#  ('350-1.wav', '降噪文件不存在'),
#  ('354-0.wav', '降噪文件不存在'),
#  ('355-0.wav', '降噪文件不存在'),
#  ('355-1.wav', '降噪文件不存在'),
#  ('356-0.wav', '降噪文件不存在'),
#  ('356-1.wav', '降噪文件不存在'),
#  ('357-0.wav', '降噪文件不存在'),
#  ('358-0.wav', '降噪文件不存在'),
#  ('358-1.wav', '降噪文件不存在'),
#  ('360-0.wav', '降噪文件不存在'),
#  ('361-0.wav', '降噪文件不存在'),
#  ('362-0.wav', '降噪文件不存在'),
#  ('362-1.wav', '降噪文件不存在'),
#  ('368-0.wav', '降噪文件不存在'),
#  ('369-0.wav', '降噪文件不存在'),
#  ('381-0.wav', '降噪文件不存在'),
#  ('381-1.wav', '降噪文件不存在'),
#  ('450-0.wav', '降噪文件不存在'),
#  ('450-1.wav', '降噪文件不存在'),
#  ('458-0.wav', '降噪文件不存在'),
#  ('461-0.wav', '降噪文件不存在'),
#  ('465-0.wav', '降噪文件不存在'),
#  ('466-0.wav', '降噪文件不存在'),
#  ('466-1.wav', '降噪文件不存在'),
#  ('468-0.wav', '降噪文件不存在'),
#  ('470-1.wav', '降噪文件不存在'),
#  ('471-0.wav', '降噪文件不存在'),
#  ('472-0.wav', '降噪文件不存在'),
#  ('474-0.wav', '降噪文件不存在'),
#  ('476-0.wav', '降噪文件不存在'),
#  ('488-0.wav', '降噪文件不存在'),
#  ('488-1.wav', '降噪文件不存在'),
#  ('492-0.wav', '降噪文件不存在'),
#  ('493-0.wav', '降噪文件不存在'),
#  ('493-1.wav', '降噪文件不存在'),
#  ('497-0.wav', '降噪文件不存在'),
#  ('497-1.wav', '降噪文件不存在'),
#  ('504-0.wav', '降噪文件不存在'),
#  ('506-0.wav', '降噪文件不存在'),
#  ('508-0.wav', '降噪文件不存在'),
#  ('508-1.wav', '降噪文件不存在'),
#  ('511-0.wav', '降噪文件不存在'),
#  ('515-1.wav', '降噪文件不存在'),
#  ('526-1.wav', '降噪文件不存在'),
#  ('527-0.wav', '降噪文件不存在'),
#  ('527-1.wav', '降噪文件不存在'),
#  ('528-0.wav', '降噪文件不存在'),
#  ('529-0.wav', '降噪文件不存在'),
#  ('530-0.wav', '降噪文件不存在'),
#  ('539-0.wav', '降噪文件不存在'),
#  ('544-0.wav', '降噪文件不存在'),
#  ('544-1.wav', '降噪文件不存在'),
#  ('551-0.wav', '降噪文件不存在'),
#  ('559-0.wav', '降噪文件不存在'),
#  ('562-0.wav', '降噪文件不存在'),
#  ('563-0.wav', '降噪文件不存在'),
#  ('573-0.wav', '降噪文件不存在'),
#  ('578-0.wav', '降噪文件不存在'),
#  ('579-0.wav', '降噪文件不存在'),
#  ('580-0.wav', '降噪文件不存在'),
#  ('581-0.wav', '降噪文件不存在'),
#  ('585-0.wav', '降噪文件不存在'),
#  ('587-0.wav', '降噪文件不存在'),
#  ('591-0.wav', '降噪文件不存在'),
#  ('592-0.wav', '降噪文件不存在'),
#  ('594-0.wav', '降噪文件不存在'),
#  ('595-0.wav', '降噪文件不存在'),
#  ('598-0.wav', '降噪文件不存在'),
#  ('601-0.wav', '降噪文件不存在'),
#  ('607-0.wav', '降噪文件不存在'),
#  ('609-0.wav', '降噪文件不存在'),
#  ('610-0.wav', '降噪文件不存在'),
#  ('615-0.wav', '降噪文件不存在'),
#  ('620-0.wav', '降噪文件不存在'),
#  ('624-0.wav', '降噪文件不存在'),
#  ('635-0.wav', '降噪文件不存在'),
#  ('636-0.wav', '降噪文件不存在'),
#  ('639-0.wav', '降噪文件不存在'),
#  ('640-0.wav', '降噪文件不存在'),
#  ('642-0.wav', '降噪文件不存在'),
#  ('648-0.wav', '降噪文件不存在'),
#  ('650-0.wav', '降噪文件不存在'),
#  ('651-0.wav', '降噪文件不存在'),
#  ('656-0.wav', '降噪文件不存在'),
#  ('657-0.wav', '降噪文件不存在'),
#  ('660-0.wav', '降噪文件不存在'),
#  ('663-0.wav', '降噪文件不存在'),
#  ('672-0.wav', '降噪文件不存在'),
#  ('674-0.wav', '降噪文件不存在'),
#  ('676-0.wav', '降噪文件不存在'),
#  ('681-0.wav', '降噪文件不存在'),
#  ('689-0.wav', '降噪文件不存在'),
#  ('690-0.wav', '降噪文件不存在'),
#  ('695-0.wav', '降噪文件不存在'),
#  ('698-0.wav', '降噪文件不存在'),
#  ('702-0.wav', '降噪文件不存在'),
#  ('703-0.wav', '降噪文件不存在'),
#  ('704-0.wav', '降噪文件不存在'),
#  ('705-0.wav', '降噪文件不存在'),
#  ('707-0.wav', '降噪文件不存在'),
#  ('711-0.wav', '降噪文件不存在'),
#  ('714-0.wav', '降噪文件不存在')]

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-MossFormer'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 35970.71it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 35515.73it/s]
# []

# %%
raw_dir = '../ad_detection/data/raw/Pitt'
denoised_dir = '../ad_detection/data/denoised/Pitt-Resemble'
output_dir = '../ad_detection/data/add/Pitt-add-1.5-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
# Out:
# 处理 Control: 100%|██████████| 242/242 [00:00<00:00, 35839.89it/s]
# 处理 Dementia: 100%|██████████| 309/309 [00:00<00:00, 35000.67it/s]
# []

# %%
RAW_WEIGHT = 0.5

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Demucs'
output_dir = '../ad_detection/data/add/Lu-add-0.5-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Denoiser'
output_dir = '../ad_detection/data/add/Lu-add-0.5-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-FRCRN_SE'
output_dir = '../ad_detection/data/add/Lu-add-0.5-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-MossFormer'
output_dir = '../ad_detection/data/add/Lu-add-0.5-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Resemble'
output_dir = '../ad_detection/data/add/Lu-add-0.5-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
RAW_WEIGHT = 1.0

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Demucs'
output_dir = '../ad_detection/data/add/Lu-add-1.0-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Denoiser'
output_dir = '../ad_detection/data/add/Lu-add-1.0-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-FRCRN_SE'
output_dir = '../ad_detection/data/add/Lu-add-1.0-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-MossFormer'
output_dir = '../ad_detection/data/add/Lu-add-1.0-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Resemble'
output_dir = '../ad_detection/data/add/Lu-add-1.0-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
RAW_WEIGHT = 1.5

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Demucs'
output_dir = '../ad_detection/data/add/Lu-add-1.5-Demucs'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Denoiser'
output_dir = '../ad_detection/data/add/Lu-add-1.5-Denoiser'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-FRCRN_SE'
output_dir = '../ad_detection/data/add/Lu-add-1.5-FRCRN_SE'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-MossFormer'
output_dir = '../ad_detection/data/add/Lu-add-1.5-MossFormer'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)

# %%
raw_dir = '../ad_detection/data/raw/Lu'
denoised_dir = '../ad_detection/data/denoised/Lu-Resemble'
output_dir = '../ad_detection/data/add/Lu-add-1.5-Resemble'

process_dataset(raw_dir, denoised_dir, output_dir, raw_weight=RAW_WEIGHT)
